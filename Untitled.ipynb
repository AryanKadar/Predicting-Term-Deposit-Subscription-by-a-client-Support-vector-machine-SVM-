# %%
import pandas as pd
import matplotlib.pyplot as mp
from sklearn.model_selection import train_test_split as TTS,GridSearchCV as GSCV
from sklearn.metrics import classification_report as CR
from sklearn.preprocessing import StandardScaler as SS,OneHotEncoder as OHE,OrdinalEncoder as OE,LabelEncoder as LE
from sklearn import set_config
import seaborn as sn
import matplotlib.pyplot as mp
import numpy as np
set_config(display="diagram")

# %%
from sklearn.compose import ColumnTransformer as CT
from sklearn.svm import SVC as svc
from sklearn.pipeline import Pipeline as PP

# %%
t=pd.read_csv("bank-additional-full.csv",delimiter=";")
t.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
t.shape
# Out:
# (41188, 21)

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
t.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
t.drop_duplicates()
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
t.drop(["age","marital","education","contact","loan","housing"],axis=1,inplace=True)

# %%
t.head()
# Out:
#          job  default month day_of_week  duration  campaign  pdays  previous  \
# 0  housemaid       no   may         mon       261         1    999         0
# 1   services  unknown   may         mon       149         1    999         0
# 2   services       no   may         mon       226         1    999         0
# 3     admin.       no   may         mon       151         1    999         0
# 4   services       no   may         mon       307         1    999         0
#
#       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0  nonexistent           1.1          93.994          -36.4      4.857
# 1  nonexistent           1.1          93.994          -36.4      4.857
# 2  nonexistent           1.1          93.994          -36.4      4.857
# 3  nonexistent           1.1          93.994          -36.4      4.857
# 4  nonexistent           1.1          93.994          -36.4      4.857
#
#    nr.employed   y
# 0       5191.0  no
# 1       5191.0  no
# ...

# %%
t.shape
# Out:
# (41188, 15)

# %%
t["y"]=LE().fit_transform(t.iloc[:,-1])

# %%
t.head()
# Out:
#          job  default month day_of_week  duration  campaign  pdays  previous  \
# 0  housemaid       no   may         mon       261         1    999         0
# 1   services  unknown   may         mon       149         1    999         0
# 2   services       no   may         mon       226         1    999         0
# 3     admin.       no   may         mon       151         1    999         0
# 4   services       no   may         mon       307         1    999         0
#
#       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0  nonexistent           1.1          93.994          -36.4      4.857
# 1  nonexistent           1.1          93.994          -36.4      4.857
# 2  nonexistent           1.1          93.994          -36.4      4.857
# 3  nonexistent           1.1          93.994          -36.4      4.857
# 4  nonexistent           1.1          93.994          -36.4      4.857
#
#    nr.employed  y
# 0       5191.0  0
# 1       5191.0  0
# ...

# %%
t.groupby("job")["y"].mean().sort_values().plot.barh();

# %%
job=t.groupby("job")["y"].mean().sort_values().keys()
job
# Out:
# Index(['blue-collar', 'services', 'entrepreneur', 'housemaid', 'self-employed',
#        'technician', 'unknown', 'management', 'admin.', 'unemployed',
#        'retired', 'student'],
#       dtype='object', name='job')

# %%
t.groupby("month")["y"].mean().sort_values().plot.barh();

# %%
month=t.groupby("month")["y"].mean().sort_values().keys()
month
# Out:
# Index(['may', 'jul', 'nov', 'jun', 'aug', 'apr', 'oct', 'sep', 'dec', 'mar'], dtype='object', name='month')

# %%
t.groupby("day_of_week")["y"].mean().sort_values().plot.barh();

# %%
d_w=t.groupby("day_of_week")["y"].mean().sort_values().keys()
d_w
# Out:
# Index(['mon', 'fri', 'wed', 'tue', 'thu'], dtype='object', name='day_of_week')

# %%
t.groupby("y")["duration"].mean().sort_values().plot.barh();

# %%
t.groupby("y")["pdays"].mean().sort_values().plot.barh();

# %%
t.pdays=np.where(t.pdays==999,0,t.pdays)

# %%
t.pdays.value_counts()
# Out:
# 0     39688
# 3       439
# 6       412
# 4       118
# 9        64
# 2        61
# 7        60
# 12       58
# 10       52
# 5        46
# 13       36
# 11       28
# 1        26
# 15       24
# 14       20
# 8        18
# 16       11
# 17        8
# 18        7
# 19        3
# 22        3
# 21        2
# 20        1
# 25        1
# 26        1
# 27        1
# Name: pdays, dtype: int64

# %%
t.groupby("poutcome")["y"].mean().sort_values().plot.barh();

# %%
poutcome=t.groupby("poutcome")["y"].mean().sort_values().keys()
poutcome
# Out:
# Index(['nonexistent', 'failure', 'success'], dtype='object', name='poutcome')

# %%
sn.scatterplot(t["cons.price.idx"],t["cons.conf.idx"]);

# %%
t.groupby("previous")["y"].mean().sort_values().plot.barh();

# %%
t.groupby("default")["y"].mean().sort_values().plot.barh();

# %%
default=t.groupby("default")["y"].mean().sort_values().keys()
default
# Out:
# Index(['yes', 'unknown', 'no'], dtype='object', name='default')

# %%
t.head()
# Out:
#          job  default month day_of_week  duration  campaign  pdays  previous  \
# 0  housemaid       no   may         mon       261         1      0         0
# 1   services  unknown   may         mon       149         1      0         0
# 2   services       no   may         mon       226         1      0         0
# 3     admin.       no   may         mon       151         1      0         0
# 4   services       no   may         mon       307         1      0         0
#
#       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0  nonexistent           1.1          93.994          -36.4      4.857
# 1  nonexistent           1.1          93.994          -36.4      4.857
# 2  nonexistent           1.1          93.994          -36.4      4.857
# 3  nonexistent           1.1          93.994          -36.4      4.857
# 4  nonexistent           1.1          93.994          -36.4      4.857
#
#    nr.employed  y
# 0       5191.0  0
# 1       5191.0  0
# ...

# %%
t=t.sample(6000)

# %%
x=t.iloc[:,:14]
x
# Out:
#                  job  default month day_of_week  duration  campaign  pdays  \
# 2989          admin.       no   may         wed       180         1      0
# 2012     blue-collar       no   may         mon       149         5      0
# 40105        retired       no   jul         mon       796         1      6
# 35175    blue-collar       no   may         fri       199         2      0
# 23740         admin.       no   aug         thu        23        14      0
# ...              ...      ...   ...         ...       ...       ...    ...
# 21364  self-employed  unknown   aug         mon       127         3      0
# 6952        services       no   may         thu       283         1      0
# 25967     technician       no   nov         wed       220         1      0
# 38083     technician       no   sep         tue       103         1      0
# 33036    blue-collar       no   may         mon       214         2      0
#
# ...

# %%
y=t.iloc[:,14]
y
# Out:
# 2989     0
# 2012     0
# 40105    1
# 35175    0
# 23740    0
#         ..
# 21364    0
# 6952     0
# 25967    0
# 38083    0
# 33036    0
# Name: y, Length: 6000, dtype: int32

# %%
xta,xte,yta,yte=TTS(x,y,test_size=0.2,random_state=3)

# %%
ct=CT(
[
    ("OE",OE(categories=[job,default,month,d_w,poutcome]),[0,1,2,3,8]),
    
]
,remainder="passthrough"
)

# %%
p={
    "C":[1,2,3,4],
    "kernel":["linear","poly","rbf","sigmoid"],
    "degree":[1,2,3],
    "gamma":["scale","auto"],
    "coef0":[0,1,2],
}

# %%
pp1=PP(
[
    ("ct",ct),
    ("SS",SS()),
    ("svm",GSCV(svc(),param_grid=p,scoring="accuracy",n_jobs=-1,cv=3))
]
)

# %%
pp1.fit(xta,yta)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('OE',
#                                                   OrdinalEncoder(categories=[Index(['blue-collar', 'services', 'entrepreneur', 'housemaid', 'self-employed',
#        'technician', 'unknown', 'management', 'admin.', 'unemployed',
#        'retired', 'student'],
#       dtype='object', name='job'),
#                                                                              Index(['yes', 'unknown', 'no'], dtype='object', name='default'...
#                                                                              Index(['mon', 'fri', 'wed', 'tue', 'thu'], dtype='object', name='day_of_week'),
#                                                                              Index(['nonexistent', 'failure', 'success'], dtype='object', name='poutcome')]),
#                                                   [0, 1, 2, 3, 8])])),
# ...

# %%
pp1.named_steps["svm"].best_score_
# Out:
# 0.9085416666666667

# %%
pp1.named_steps["svm"].best_params_
# Out:
# {'C': 1, 'coef0': 2, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
